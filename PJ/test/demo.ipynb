# %%
import os

root_dir = "./input_example"
for dirpath, _, filenames in os.walk(root_dir):
    quad_files = [f for f in filenames if f.endswith(".4-ssa.quad")]

    for quad_file in quad_files:
        quad_my_file = quad_file.replace(".4-ssa.quad", ".4-ssa.quad.my")
        quad_path = os.path.join(dirpath, quad_file)
        quad_my_path = os.path.join(dirpath, quad_my_file)

        print(os.path.relpath(quad_path, root_dir))

        # 第一次遍历：比较行数
        with open(quad_path) as f1, open(quad_my_path) as f2:
            lines1 = sum(1 for _ in f1)
            lines2 = sum(1 for _ in f2)
            assert lines1 == lines2, f"行数不匹配: {lines1} vs {lines2}"

        # 第二次遍历：逐行严格比较
        with open(quad_path) as f1, open(quad_my_path) as f2:
            line_num = 0

            for line1, line2 in zip(f1, f2):
                line_num += 1


                if len(line1) != len(line2):  # 严格比较，包括所有空白字符
                    line1_part = line1.split("use:")
                    line2_part = line2.split("use:")
                    
                    if line1_part[0] == line2_part[0]:
                        line1_use = line1_part[1].strip().split(" ")
                        line2_use = line2_part[1].strip().split(" ")
                        if set(line1_use) == set(line2_use):
                            continue
                    
                    print(f"  第{line_num}行:")
                    print(f"  {quad_path}   : {repr(line1)}")
                    print(f"  {quad_my_path}: {repr(line2)}")
# Out:
# hw8test10.4-ssa.quad
# hw8test12.4-ssa.quad
# hw8test07.4-ssa.quad
# hw8test06.4-ssa.quad
#   第52行:
#   ./input_example/hw8test06.4-ssa.quad   : '    MOVE_CALL t119:PTR <- next[t11200:PTR] (t11100:PTR, t11000:INT); def: use: 11100 11200 11000 \n'
#   ./input_example/hw8test06.4-ssa.quad.my: '    MOVE_CALL t11300:PTR <- next[t10700:PTR] (t10600:PTR, t10500:INT); def: 11300 use: 10700 10600 10500 \n'
#   第53行:
#   ./input_example/hw8test06.4-ssa.quad   : '    STORE t119:PTR -> Mem(t11800:PTR); def: use: 11800 119 \n'
#   ./input_example/hw8test06.4-ssa.quad.my: '    STORE t11300:PTR -> Mem(t11200:PTR); def: use: 11200 11300 \n'
# hw8test09.4-ssa.quad
#   第49行:
#   ./input_example/hw8test09.4-ssa.quad   : '    STORE Name:C1^m -> Mem(t11100:PTR); def: use: 11100 \n'
#   ./input_example/hw8test09.4-ssa.quad.my: '    STORE Name:C^f -> Mem(t10800:PTR); def: use: 10800 \n'
#   第51行:
#   ./input_example/hw8test09.4-ssa.quad   : '    STORE Name:C^f -> Mem(t11200:PTR); def: use: 11200 \n'
#   ./input_example/hw8test09.4-ssa.quad.my: '    STORE Name:C1^m -> Mem(t10900:PTR); def: use: 10900 \n'
# hw8test02.4-ssa.quad
# bubblesort.4-ssa.quad
#   第5行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_EXTCALL t10000:PTR <- malloc(Const:32); def: 10000 use: \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE t10200:INT <- Const:0; def: 10200 use: \n'
#   第6行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:7 -> Mem(t10000:PTR); def: use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_EXTCALL t10000:PTR <- malloc(Const:32); def: 10000 use: \n'
#   第7行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t12400:PTR <- (+, t10000:PTR, Const:4); def: 12400 use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:7 -> Mem(t10000:PTR); def: use: 10000 \n'
#   第8行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:6 -> Mem(t12400:PTR); def: use: 12400 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12000:PTR <- (+, t10000:PTR, Const:4); def: 12000 use: 10000 \n'
#   第9行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t12500:PTR <- (+, t10000:PTR, Const:8); def: 12500 use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:6 -> Mem(t12000:PTR); def: use: 12000 \n'
#   第10行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:3 -> Mem(t12500:PTR); def: use: 12500 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12100:PTR <- (+, t10000:PTR, Const:8); def: 12100 use: 10000 \n'
#   第11行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t12600:PTR <- (+, t10000:PTR, Const:12); def: 12600 use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:3 -> Mem(t12100:PTR); def: use: 12100 \n'
#   第12行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:0 -> Mem(t12600:PTR); def: use: 12600 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12200:PTR <- (+, t10000:PTR, Const:12); def: 12200 use: 10000 \n'
#   第13行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t12700:PTR <- (+, t10000:PTR, Const:16); def: 12700 use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:0 -> Mem(t12200:PTR); def: use: 12200 \n'
#   第14行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:5 -> Mem(t12700:PTR); def: use: 12700 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12300:PTR <- (+, t10000:PTR, Const:16); def: 12300 use: 10000 \n'
#   第15行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t12800:PTR <- (+, t10000:PTR, Const:20); def: 12800 use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:5 -> Mem(t12300:PTR); def: use: 12300 \n'
#   第16行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:9 -> Mem(t12800:PTR); def: use: 12800 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12400:PTR <- (+, t10000:PTR, Const:20); def: 12400 use: 10000 \n'
#   第17行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t12900:PTR <- (+, t10000:PTR, Const:24); def: 12900 use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:9 -> Mem(t12400:PTR); def: use: 12400 \n'
#   第18行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:1 -> Mem(t12900:PTR); def: use: 12900 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12500:PTR <- (+, t10000:PTR, Const:24); def: 12500 use: 10000 \n'
#   第19行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t13000:PTR <- (+, t10000:PTR, Const:28); def: 13000 use: 10000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:1 -> Mem(t12500:PTR); def: use: 12500 \n'
#   第20行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Const:2 -> Mem(t13000:PTR); def: use: 13000 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12600:PTR <- (+, t10000:PTR, Const:28); def: 12600 use: 10000 \n'
#   第21行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_EXTCALL t10100:PTR <- malloc(Const:8); def: 10100 use: \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Const:2 -> Mem(t12600:PTR); def: use: 12600 \n'
#   第22行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE_BINOP t13200:PTR <- (+, t10100:PTR, Const:4); def: 13200 use: 10100 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_EXTCALL t10100:PTR <- malloc(Const:8); def: 10100 use: \n'
#   第23行:
#   ./input_example/bubblesort.4-ssa.quad   : '    STORE Name:b1^bubbleSort -> Mem(t13200:PTR); def: use: 13200 \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    MOVE_BINOP t12700:PTR <- (+, t10100:PTR, Const:4); def: 12700 use: 10100 \n'
#   第24行:
#   ./input_example/bubblesort.4-ssa.quad   : '    MOVE t10200:INT <- Const:0; def: 10200 use: \n'
#   ./input_example/bubblesort.4-ssa.quad.my: '    STORE Name:b1^bubbleSort -> Mem(t12700:PTR); def: use: 12700 \n'
# hw8test01.4-ssa.quad
# hw8test11.4-ssa.quad
# hw8test05.4-ssa.quad
# hw8test04.4-ssa.quad
# hw8test00.4-ssa.quad
# hw8test08.4-ssa.quad
# fibonacci.4-ssa.quad
# hw8test03.4-ssa.quad
