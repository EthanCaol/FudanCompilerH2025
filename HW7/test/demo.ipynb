# %%
import os

root_dir = "./"
for dirpath, _, filenames in os.walk(root_dir):
    quad_files = [f for f in filenames if f.endswith(".4-ssa.quad")]

    for quad_file in quad_files:
        quad_my_file = quad_file.replace(".4-ssa.quad", ".4-ssa.quad-my")
        quad_path = os.path.join(dirpath, quad_file)
        quad_my_path = os.path.join(dirpath, quad_my_file)

        print(os.path.relpath(quad_path, root_dir))

        # 第一次遍历：比较行数
        with open(quad_path) as f1, open(quad_my_path) as f2:
            lines1 = sum(1 for _ in f1)
            lines2 = sum(1 for _ in f2)
            assert lines1 == lines2, f"行数不匹配: {lines1} vs {lines2}"

        # 第二次遍历：逐行严格比较
        with open(quad_path) as f1, open(quad_my_path) as f2:
            line_num = 0

            for line1, line2 in zip(f1, f2):
                line_num += 1

                if line1 != line2:  # 严格比较，包括所有空白字符
                    print(f"  第{line_num}行:")
                    print(f"  {quad_path}   : {repr(line1)}")
                    print(f"  {quad_my_path}: {repr(line2)}")
# Out:
# HW3/hw3test06.4-ssa.quad
# HW3/hw3test01.4-ssa.quad
#   第46行:
#   ./HW3/hw3test01.4-ssa.quad   : '    CJUMP < t10901:INT t11000:INT? L103 : L104; def: use: 10901 11000 \n'
#   ./HW3/hw3test01.4-ssa.quad-my: '    CJUMP < t10901:INT t11000:INT? L103 : L104; def: use: 11000 10901 \n'
# HW3/hw3test04.4-ssa.quad
#   第76行:
#   ./HW3/hw3test04.4-ssa.quad   : '    PHI t10102:PTR <- (t10101, L106; t10100, L107); def: 10102 use: 10101 10100 \n'
#   ./HW3/hw3test04.4-ssa.quad-my: '    PHI t10102:PTR <- (t10101, L106; t10100, L107); def: 10102 use: 10100 10101 \n'
# Other/test4.4-ssa.quad
#   第21行:
#   ./Other/test4.4-ssa.quad   : '    PHI t10201:INT <- (t10202, L106; t10200, L107); def: 10201 use: 10200 10202 \n'
#   ./Other/test4.4-ssa.quad-my: '    PHI t10201:INT <- (t10200, L107; t10202, L106); def: 10201 use: 10200 10202 \n'
#   第22行:
#   ./Other/test4.4-ssa.quad   : '    PHI t10101:INT <- (t10102, L106; t10100, L107); def: 10101 use: 10100 10102 \n'
#   ./Other/test4.4-ssa.quad-my: '    PHI t10101:INT <- (t10100, L107; t10102, L106); def: 10101 use: 10100 10102 \n'
# Other/test2.4-ssa.quad
#   第7行:
#   ./Other/test2.4-ssa.quad   : '    MOVE_BINOP t10300:INT <- (+, t10100:INT, t10200:INT); def: 10300 use: 10200 10100 \n'
#   ./Other/test2.4-ssa.quad-my: '    MOVE_BINOP t10300:INT <- (+, t10100:INT, t10200:INT); def: 10300 use: 10100 10200 \n'
# Other/test5.4-ssa.quad
# Other/test10.4-ssa.quad
# Other/test3.4-ssa.quad
#   第49行:
#   ./Other/test3.4-ssa.quad   : '    CJUMP < t11001:INT t11100:INT? L103 : L104; def: use: 11001 11100 \n'
#   ./Other/test3.4-ssa.quad-my: '    CJUMP < t11001:INT t11100:INT? L103 : L104; def: use: 11100 11001 \n'
# Other/test8.4-ssa.quad
#   第41行:
#   ./Other/test8.4-ssa.quad   : '    PHI t10401:INT <- (t10402, L106; t10400, L115); def: 10401 use: 10400 10402 \n'
#   ./Other/test8.4-ssa.quad-my: '    PHI t10401:INT <- (t10400, L115; t10402, L106); def: 10401 use: 10400 10402 \n'
#   第42行:
#   ./Other/test8.4-ssa.quad   : '    CJUMP < t10401:INT t10500:INT? L103 : L104; def: use: 10401 10500 \n'
#   ./Other/test8.4-ssa.quad-my: '    CJUMP < t10401:INT t10500:INT? L103 : L104; def: use: 10500 10401 \n'
#   第89行:
#   ./Other/test8.4-ssa.quad   : '    CJUMP < t11601:INT t11700:INT? L110 : L111; def: use: 11601 11700 \n'
#   ./Other/test8.4-ssa.quad-my: '    CJUMP < t11601:INT t11700:INT? L110 : L111; def: use: 11700 11601 \n'
#   第119行:
#   ./Other/test8.4-ssa.quad   : '    CJUMP < t12001:INT t12100:INT? L113 : L114; def: use: 12001 12100 \n'
#   ./Other/test8.4-ssa.quad-my: '    CJUMP < t12001:INT t12100:INT? L113 : L114; def: use: 12100 12001 \n'
# Other/test11.4-ssa.quad
#   第33行:
#   ./Other/test11.4-ssa.quad   : '    CJUMP < t11001:INT t11100:INT? L103 : L104; def: use: 11001 11100 \n'
#   ./Other/test11.4-ssa.quad-my: '    CJUMP < t11001:INT t11100:INT? L103 : L104; def: use: 11100 11001 \n'
# Other/test0.4-ssa.quad
#   第21行:
#   ./Other/test0.4-ssa.quad   : '    PHI t10601:INT <- (t10602, L101; t10600, L105); def: 10601 use: 10600 10602 \n'
#   ./Other/test0.4-ssa.quad-my: '    PHI t10601:INT <- (t10600, L105; t10602, L101); def: 10601 use: 10600 10602 \n'
#   第22行:
#   ./Other/test0.4-ssa.quad   : '    CJUMP < t10601:INT t10700:INT? L101 : L102; def: use: 10601 10700 \n'
#   ./Other/test0.4-ssa.quad-my: '    CJUMP < t10601:INT t10700:INT? L101 : L102; def: use: 10700 10601 \n'
# Other/test9.4-ssa.quad
#   第29行:
#   ./Other/test9.4-ssa.quad   : '    STORE t101:INT -> Mem(t10400:PTR); def: use: 101 10400 \n'
#   ./Other/test9.4-ssa.quad-my: '    STORE t101:INT -> Mem(t10400:PTR); def: use: 10400 101 \n'
#   第37行:
#   ./Other/test9.4-ssa.quad   : '    MOVE_CALL t10600:PTR <- m1[t10500:PTR] (t100:PTR, t101:INT); def: 10600 use: 100 101 10500 \n'
#   ./Other/test9.4-ssa.quad-my: '    MOVE_CALL t10600:PTR <- m1[t10500:PTR] (t100:PTR, t101:INT); def: 10600 use: 100 10500 101 \n'
#   第42行:
#   ./Other/test9.4-ssa.quad   : '    MOVE_BINOP t11200:INT <- (+, t10900:INT, t11100:INT); def: 11200 use: 10900 11100 \n'
#   ./Other/test9.4-ssa.quad-my: '    MOVE_BINOP t11200:INT <- (+, t10900:INT, t11100:INT); def: 11200 use: 11100 10900 \n'
# Other/bubblesort.4-ssa.quad
#   第36行:
#   ./Other/bubblesort.4-ssa.quad   : '    PHI t10201:INT <- (t10202, L106; t10200, L107); def: 10201 use: 10200 10202 \n'
#   ./Other/bubblesort.4-ssa.quad-my: '    PHI t10201:INT <- (t10200, L107; t10202, L106); def: 10201 use: 10200 10202 \n'
#   第105行:
#   ./Other/bubblesort.4-ssa.quad   : '    MOVE_BINOP t13700:PTR <- (+, t11600:PTR, t13600:INT); def: 13700 use: 11600 13600 \n'
#   ./Other/bubblesort.4-ssa.quad-my: '    MOVE_BINOP t13700:PTR <- (+, t11600:PTR, t13600:INT); def: 13700 use: 13600 11600 \n'
#   第138行:
#   ./Other/bubblesort.4-ssa.quad   : '    MOVE_BINOP t14400:PTR <- (+, t12100:PTR, t14300:INT); def: 14400 use: 14300 12100 \n'
#   ./Other/bubblesort.4-ssa.quad-my: '    MOVE_BINOP t14400:PTR <- (+, t12100:PTR, t14300:INT); def: 14400 use: 12100 14300 \n'
#   第172行:
#   ./Other/bubblesort.4-ssa.quad   : '    CJUMP >= t11300:INT t11400:INT? L122 : L123; def: use: 11400 11300 \n'
#   ./Other/bubblesort.4-ssa.quad-my: '    CJUMP >= t11300:INT t11400:INT? L122 : L123; def: use: 11300 11400 \n'
#   第203行:
#   ./Other/bubblesort.4-ssa.quad   : '    MOVE_CALL t13300:INT <- bubbleSort[t13200:PTR] (t13100:PTR, t13000:PTR, t12900:INT); def: 13300 use: 12900 13000 13100 13200 \n'
#   ./Other/bubblesort.4-ssa.quad-my: '    MOVE_CALL t13300:INT <- bubbleSort[t13200:PTR] (t13100:PTR, t13000:PTR, t12900:INT); def: 13300 use: 13200 13100 13000 12900 \n'
# Other/test1.4-ssa.quad
# Other/fibonacci.4-ssa.quad
#   第57行:
#   ./Other/fibonacci.4-ssa.quad   : '    PHI t10001:INT <- (t10000, L107; t10002, L111); def: 10001 use: 10000 10002 \n'
#   ./Other/fibonacci.4-ssa.quad-my: '    PHI t10001:INT <- (t10000, L107; t10002, L111); def: 10001 use: 10002 10000 \n'
#   第58行:
#   ./Other/fibonacci.4-ssa.quad   : '    CJUMP < t10001:INT t10100:INT? L111 : L112; def: use: 10001 10100 \n'
#   ./Other/fibonacci.4-ssa.quad-my: '    CJUMP < t10001:INT t10100:INT? L111 : L112; def: use: 10100 10001 \n'
#   第64行:
#   ./Other/fibonacci.4-ssa.quad   : '    MOVE_CALL t13200:INT <- f[t13100:PTR] (t10200:PTR, t10001:INT); def: 13200 use: 10200 10001 13100 \n'
#   ./Other/fibonacci.4-ssa.quad-my: '    MOVE_CALL t13200:INT <- f[t13100:PTR] (t10200:PTR, t10001:INT); def: 13200 use: 10001 13100 10200 \n'
#   第96行:
#   ./Other/fibonacci.4-ssa.quad   : '    MOVE_CALL t10700:INT <- f[t10600:PTR] (t10500:PTR, t10400:INT); def: 10700 use: 10600 10500 10400 \n'
#   ./Other/fibonacci.4-ssa.quad-my: '    MOVE_CALL t10700:INT <- f[t10600:PTR] (t10500:PTR, t10400:INT); def: 10700 use: 10400 10500 10600 \n'
# Other/test6.4-ssa.quad
# Other/test7.4-ssa.quad
# HW4/hw4test02.4-ssa.quad
#   第26行:
#   ./HW4/hw4test02.4-ssa.quad   : '    PHI t10202:INT <- (t10200, L104; t10200, L107; t10201, L108); def: 10202 use: 10200 10200 10201 \n'
#   ./HW4/hw4test02.4-ssa.quad-my: '    PHI t10202:INT <- (t10200, L107; t10200, L104; t10201, L108); def: 10202 use: 10200 10201 \n'
# HW4/hw4test04.4-ssa.quad
#   第17行:
#   ./HW4/hw4test04.4-ssa.quad   : '    PHI t10302:INT <- (t10301, L102; t10300, L110); def: 10302 use: 10300 10301 \n'
#   ./HW4/hw4test04.4-ssa.quad-my: '    PHI t10302:INT <- (t10300, L110; t10301, L102); def: 10302 use: 10300 10301 \n'
# HW4/hw4test08.4-ssa.quad
#   第33行:
#   ./HW4/hw4test08.4-ssa.quad   : '    PHI t10003:INT <- (t10002, L107; t10001, L108); def: 10003 use: 10002 10001 \n'
#   ./HW4/hw4test08.4-ssa.quad-my: '    PHI t10003:INT <- (t10002, L107; t10001, L108); def: 10003 use: 10001 10002 \n'
#   第47行:
#   ./HW4/hw4test08.4-ssa.quad   : '    PHI t10102:INT <- (t10101, L112; t10100, L113); def: 10102 use: 10101 10100 \n'
#   ./HW4/hw4test08.4-ssa.quad-my: '    PHI t10102:INT <- (t10101, L112; t10100, L113); def: 10102 use: 10100 10101 \n'
# HW4/hw4test01.4-ssa.quad
# HW4/hw4test06.4-ssa.quad
# HW4/hw4test09.4-ssa.quad
#   第16行:
#   ./HW4/hw4test09.4-ssa.quad   : '    PHI t10302:INT <- (t10301, L102; t10300, L105); def: 10302 use: 10300 10301 \n'
#   ./HW4/hw4test09.4-ssa.quad-my: '    PHI t10302:INT <- (t10300, L105; t10301, L102); def: 10302 use: 10300 10301 \n'
# HW4/hw4test10.4-ssa.quad
#   第18行:
#   ./HW4/hw4test10.4-ssa.quad   : '    PHI t10302:INT <- (t10301, L102; t10300, L119); def: 10302 use: 10300 10301 \n'
#   ./HW4/hw4test10.4-ssa.quad-my: '    PHI t10302:INT <- (t10300, L119; t10301, L102); def: 10302 use: 10300 10301 \n'
#   第41行:
#   ./HW4/hw4test10.4-ssa.quad   : '    PHI t10402:INT <- (t10400, L114; t10400, L115; t10401, L116); def: 10402 use: 10400 10400 10401 \n'
#   ./HW4/hw4test10.4-ssa.quad-my: '    PHI t10402:INT <- (t10400, L115; t10400, L114; t10401, L116); def: 10402 use: 10400 10401 \n'
# HW4/hw4test07.4-ssa.quad
# HW4/hw4test05.4-ssa.quad
# HW4/hw4test03.4-ssa.quad
#   第15行:
#   ./HW4/hw4test03.4-ssa.quad   : '    PHI t10202:INT <- (t10201, L102; t10200, L105); def: 10202 use: 10200 10201 \n'
#   ./HW4/hw4test03.4-ssa.quad-my: '    PHI t10202:INT <- (t10200, L105; t10201, L102); def: 10202 use: 10200 10201 \n'
