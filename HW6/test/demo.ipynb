# %%
import os

root_dir = "./"
for dirpath, _, filenames in os.walk(root_dir):
    quad_files = [f for f in filenames if f.endswith(".4.quad")]

    for quad_file in quad_files:
        quad_my_file = quad_file.replace(".4.quad", ".4.quad-my")
        quad_path = os.path.join(dirpath, quad_file)
        quad_my_path = os.path.join(dirpath, quad_my_file)

        print(os.path.relpath(quad_path, root_dir))

        # 第一次遍历：比较行数
        with open(quad_path) as f1, open(quad_my_path) as f2:
            lines1 = sum(1 for _ in f1)
            lines2 = sum(1 for _ in f2)
            assert lines1 == lines2, f"行数不匹配: {lines1} vs {lines2}"

        # 第二次遍历：逐行严格比较
        with open(quad_path) as f1, open(quad_my_path) as f2:
            line_num = 0

            for line1, line2 in zip(f1, f2):
                line_num += 1

                if line1 != line2:  # 严格比较，包括所有空白字符
                    print(f"  第 {line_num} 行:")
                    print(f"    {quad_path}: {repr(line1)}")
                    print(f"    {quad_my_path}: {repr(line2)}")
# Out:
# HW4/hw4test04.4.quad
#   第 12 行:
#     ./HW4/hw4test04.4.quad: '    MOVE_BINOP t100:INT <- (+, t104:INT, t103:INT); def: 100 use: 104 103 \n'
#     ./HW4/hw4test04.4.quad-my: '    MOVE_BINOP t100:INT <- (+, t104:INT, t103:INT); def: 100 use: 103 104 \n'
# HW4/hw4test06.4.quad
# HW4/hw4test05.4.quad
#   第 15 行:
#     ./HW4/hw4test05.4.quad: '    MOVE_BINOP t100:INT <- (+, t104:INT, t103:INT); def: 100 use: 104 103 \n'
#     ./HW4/hw4test05.4.quad-my: '    MOVE_BINOP t100:INT <- (+, t104:INT, t103:INT); def: 100 use: 103 104 \n'
# HW4/hw4test01.4.quad
# HW4/hw4test08.4.quad
# HW4/hw4test03.4.quad
# HW4/hw4test10.4.quad
#   第 13 行:
#     ./HW4/hw4test10.4.quad: '    MOVE_BINOP t106:INT <- (+, t105:INT, t103:INT); def: 106 use: 105 103 \n'
#     ./HW4/hw4test10.4.quad-my: '    MOVE_BINOP t106:INT <- (+, t105:INT, t103:INT); def: 106 use: 103 105 \n'
# HW4/hw4test09.4.quad
# HW4/hw4test07.4.quad
# HW4/hw4test02.4.quad
# Func/fibonacci.4.quad
# Func/bubblesort.4.quad
#   第 89 行:
#     ./Func/bubblesort.4.quad: '    LOAD t141:INT <- Mem(t140:PTR); def: 141 use: 140 \n'
#     ./Func/bubblesort.4.quad-my: '    LOAD t141:PTR <- Mem(t140:PTR); def: 141 use: 140 \n'
#   第 90 行:
#     ./Func/bubblesort.4.quad: '    CJUMP > t119:INT t141:INT? L124 : L125; def: use: 119 141 \n'
#     ./Func/bubblesort.4.quad-my: '    CJUMP > t119:INT t141:PTR? L124 : L125; def: use: 119 141 \n'
#   第 121 行:
#     ./Func/bubblesort.4.quad: '    LOAD t151:INT <- Mem(t150:PTR); def: 151 use: 150 \n'
#     ./Func/bubblesort.4.quad-my: '    LOAD t151:PTR <- Mem(t150:PTR); def: 151 use: 150 \n'
#   第 122 行:
#     ./Func/bubblesort.4.quad: '    STORE t151:INT -> Mem(t147:PTR); def: use: 147 151 \n'
#     ./Func/bubblesort.4.quad-my: '    STORE t151:PTR -> Mem(t147:PTR); def: use: 147 151 \n'
# HW5/test10.4.quad
# HW5/test11.4.quad
#   第 29 行:
#     ./HW5/test11.4.quad: '    LOAD t122:INT <- Mem(t121:PTR); def: 122 use: 121 \n'
#     ./HW5/test11.4.quad-my: '    LOAD t122:PTR <- Mem(t121:PTR); def: 122 use: 121 \n'
#   第 31 行:
#     ./HW5/test11.4.quad: '    LOAD t124:INT <- Mem(t123:PTR); def: 124 use: 123 \n'
#     ./HW5/test11.4.quad-my: '    LOAD t124:PTR <- Mem(t123:PTR); def: 124 use: 123 \n'
#   第 32 行:
#     ./HW5/test11.4.quad: '    MOVE_BINOP t125:INT <- (+, t122:INT, t124:INT); def: 125 use: 122 124 \n'
#     ./HW5/test11.4.quad-my: '    MOVE_BINOP t125:INT <- (+, t122:PTR, t124:PTR); def: 125 use: 122 124 \n'
# HW5/test8.4.quad
#   第 72 行:
#     ./HW5/test8.4.quad: '    LOAD t157:INT <- Mem(t156:PTR); def: 157 use: 156 \n'
#     ./HW5/test8.4.quad-my: '    LOAD t157:PTR <- Mem(t156:PTR); def: 157 use: 156 \n'
#   第 74 行:
#     ./HW5/test8.4.quad: '    LOAD t159:INT <- Mem(t158:PTR); def: 159 use: 158 \n'
#     ./HW5/test8.4.quad-my: '    LOAD t159:PTR <- Mem(t158:PTR); def: 159 use: 158 \n'
#   第 75 行:
#     ./HW5/test8.4.quad: '    MOVE_BINOP t160:INT <- (+, t157:INT, t159:INT); def: 160 use: 157 159 \n'
#     ./HW5/test8.4.quad-my: '    MOVE_BINOP t160:INT <- (+, t157:PTR, t159:PTR); def: 160 use: 157 159 \n'
#   第 94 行:
#     ./HW5/test8.4.quad: '    LOAD t165:INT <- Mem(t164:PTR); def: 165 use: 164 \n'
#     ./HW5/test8.4.quad-my: '    LOAD t165:PTR <- Mem(t164:PTR); def: 165 use: 164 \n'
#   第 95 行:
#     ./HW5/test8.4.quad: '    MOVE_BINOP t166:INT <- (-, Const:0, t165:INT); def: 166 use: 165 \n'
#     ./HW5/test8.4.quad-my: '    MOVE_BINOP t166:INT <- (-, Const:0, t165:PTR); def: 166 use: 165 \n'
# HW5/test9.4.quad
#   第 13 行:
#     ./HW5/test9.4.quad: '    LOAD t118:INT <- Mem(t117:PTR); def: 118 use: 117 \n'
#     ./HW5/test9.4.quad-my: '    LOAD t118:PTR <- Mem(t117:PTR); def: 118 use: 117 \n'
#   第 14 行:
#     ./HW5/test9.4.quad: '    MOVE_BINOP t119:INT <- (*, Const:3, t118:INT); def: 119 use: 118 \n'
#     ./HW5/test9.4.quad-my: '    MOVE_BINOP t119:INT <- (*, Const:3, t118:PTR); def: 119 use: 118 \n'
#   第 39 行:
#     ./HW5/test9.4.quad: '    LOAD t109:INT <- Mem(t108:PTR); def: 109 use: 108 \n'
#     ./HW5/test9.4.quad-my: '    LOAD t109:PTR <- Mem(t108:PTR); def: 109 use: 108 \n'
#   第 41 行:
#     ./HW5/test9.4.quad: '    LOAD t111:INT <- Mem(t110:PTR); def: 111 use: 110 \n'
#     ./HW5/test9.4.quad-my: '    LOAD t111:PTR <- Mem(t110:PTR); def: 111 use: 110 \n'
#   第 42 行:
#     ./HW5/test9.4.quad: '    MOVE_BINOP t112:INT <- (+, t109:INT, t111:INT); def: 112 use: 109 111 \n'
#     ./HW5/test9.4.quad-my: '    MOVE_BINOP t112:INT <- (+, t109:PTR, t111:PTR); def: 112 use: 109 111 \n'
# HW5/test2.4.quad
# HW5/test1.4.quad
#   第 10 行:
#     ./HW5/test1.4.quad: '    CALL m[t103:PTR] (t100:PTR); def: use: 103 100 \n'
#     ./HW5/test1.4.quad-my: '    CALL m[t103:PTR] (t100:PTR); def: use: 100 103 \n'
# HW5/test0.4.quad
#   第 21 行:
#     ./HW5/test0.4.quad: '    LOAD t120:INT <- Mem(t119:PTR); def: 120 use: 119 \n'
#     ./HW5/test0.4.quad-my: '    LOAD t120:PTR <- Mem(t119:PTR); def: 120 use: 119 \n'
#   第 22 行:
#     ./HW5/test0.4.quad: '    MOVE_BINOP t121:INT <- (-, Const:0, t120:INT); def: 121 use: 120 \n'
#     ./HW5/test0.4.quad-my: '    MOVE_BINOP t121:INT <- (-, Const:0, t120:PTR); def: 121 use: 120 \n'
#   第 23 行:
#     ./HW5/test0.4.quad: '    STORE t121:INT -> Mem(t118:PTR); def: use: 118 121 \n'
#     ./HW5/test0.4.quad-my: '    STORE t121:INT -> Mem(t118:PTR); def: use: 121 118 \n'
#   第 38 行:
#     ./HW5/test0.4.quad: '    LOAD t125:INT <- Mem(t124:PTR); def: 125 use: 124 \n'
#     ./HW5/test0.4.quad-my: '    LOAD t125:PTR <- Mem(t124:PTR); def: 125 use: 124 \n'
#   第 39 行:
#     ./HW5/test0.4.quad: '    RETURN t125:INT; def: use: 125 \n'
#     ./HW5/test0.4.quad-my: '    RETURN t125:PTR; def: use: 125 \n'
# HW5/test3.4.quad
#   第 45 行:
#     ./HW5/test3.4.quad: '    LOAD t133:INT <- Mem(t132:PTR); def: 133 use: 132 \n'
#     ./HW5/test3.4.quad-my: '    LOAD t133:PTR <- Mem(t132:PTR); def: 133 use: 132 \n'
#   第 47 行:
#     ./HW5/test3.4.quad: '    LOAD t135:INT <- Mem(t134:PTR); def: 135 use: 134 \n'
#     ./HW5/test3.4.quad-my: '    LOAD t135:PTR <- Mem(t134:PTR); def: 135 use: 134 \n'
#   第 48 行:
#     ./HW5/test3.4.quad: '    MOVE_BINOP t136:INT <- (+, t133:INT, t135:INT); def: 136 use: 133 135 \n'
#     ./HW5/test3.4.quad-my: '    MOVE_BINOP t136:INT <- (+, t133:PTR, t135:PTR); def: 136 use: 133 135 \n'
#   第 63 行:
#     ./HW5/test3.4.quad: '    LOAD t140:INT <- Mem(t139:PTR); def: 140 use: 139 \n'
#     ./HW5/test3.4.quad-my: '    LOAD t140:PTR <- Mem(t139:PTR); def: 140 use: 139 \n'
#   第 64 行:
#     ./HW5/test3.4.quad: '    RETURN t140:INT; def: use: 140 \n'
#     ./HW5/test3.4.quad-my: '    RETURN t140:PTR; def: use: 140 \n'
# HW5/test6.4.quad
# HW5/test5.4.quad
#   第 10 行:
#     ./HW5/test5.4.quad: '    CALL m[t103:PTR] (t100:PTR); def: use: 103 100 \n'
#     ./HW5/test5.4.quad-my: '    CALL m[t103:PTR] (t100:PTR); def: use: 100 103 \n'
# HW5/test7.4.quad
# HW5/test4.4.quad
#   第 30 行:
#     ./HW5/test4.4.quad: '    LOAD t117:INT <- Mem(t116:PTR); def: 117 use: 116 \n'
#     ./HW5/test4.4.quad-my: '    LOAD t117:PTR <- Mem(t116:PTR); def: 117 use: 116 \n'
#   第 31 行:
#     ./HW5/test4.4.quad: '    MOVE_BINOP t102:INT <- (+, t109:INT, t117:INT); def: 102 use: 109 117 \n'
#     ./HW5/test4.4.quad-my: '    MOVE_BINOP t102:INT <- (+, t109:INT, t117:PTR); def: 102 use: 109 117 \n'
# HW3/hw3test06.4.quad
#   第 10 行:
#     ./HW3/hw3test06.4.quad: '    LOAD t107:INT <- Mem(t106:PTR); def: 107 use: 106 \n'
#     ./HW3/hw3test06.4.quad-my: '    LOAD t107:PTR <- Mem(t106:PTR); def: 107 use: 106 \n'
#   第 11 行:
#     ./HW3/hw3test06.4.quad: '    RETURN t107:INT; def: use: 107 \n'
#     ./HW3/hw3test06.4.quad-my: '    RETURN t107:PTR; def: use: 107 \n'
# HW3/hw3test04.4.quad
#   第 54 行:
#     ./HW3/hw3test04.4.quad: '    LOAD t138:INT <- Mem(t137:PTR); def: 138 use: 137 \n'
#     ./HW3/hw3test04.4.quad-my: '    LOAD t138:PTR <- Mem(t137:PTR); def: 138 use: 137 \n'
#   第 55 行:
#     ./HW3/hw3test04.4.quad: '    CJUMP < t138:INT Const:1? L106 : L107; def: use: 138 \n'
#     ./HW3/hw3test04.4.quad-my: '    CJUMP < t138:PTR Const:1? L106 : L107; def: use: 138 \n'
#   第 76 行:
#     ./HW3/hw3test04.4.quad: '    LOAD t142:INT <- Mem(t141:PTR); def: 142 use: 141 \n'
#     ./HW3/hw3test04.4.quad-my: '    LOAD t142:PTR <- Mem(t141:PTR); def: 142 use: 141 \n'
#   第 77 行:
#     ./HW3/hw3test04.4.quad: '    RETURN t142:INT; def: use: 142 \n'
#     ./HW3/hw3test04.4.quad-my: '    RETURN t142:PTR; def: use: 142 \n'
# HW3/hw3test01.4.quad
#   第 42 行:
#     ./HW3/hw3test01.4.quad: '    LOAD t130:INT <- Mem(t129:PTR); def: 130 use: 129 \n'
#     ./HW3/hw3test01.4.quad-my: '    LOAD t130:PTR <- Mem(t129:PTR); def: 130 use: 129 \n'
#   第 44 行:
#     ./HW3/hw3test01.4.quad: '    LOAD t132:INT <- Mem(t131:PTR); def: 132 use: 131 \n'
#     ./HW3/hw3test01.4.quad-my: '    LOAD t132:PTR <- Mem(t131:PTR); def: 132 use: 131 \n'
#   第 45 行:
#     ./HW3/hw3test01.4.quad: '    MOVE_BINOP t133:INT <- (+, t130:INT, t132:INT); def: 133 use: 130 132 \n'
#     ./HW3/hw3test01.4.quad-my: '    MOVE_BINOP t133:INT <- (+, t130:PTR, t132:PTR); def: 133 use: 130 132 \n'
#   第 60 行:
#     ./HW3/hw3test01.4.quad: '    LOAD t137:INT <- Mem(t136:PTR); def: 137 use: 136 \n'
#     ./HW3/hw3test01.4.quad-my: '    LOAD t137:PTR <- Mem(t136:PTR); def: 137 use: 136 \n'
#   第 61 行:
#     ./HW3/hw3test01.4.quad: '    RETURN t137:INT; def: use: 137 \n'
#     ./HW3/hw3test01.4.quad-my: '    RETURN t137:PTR; def: use: 137 \n'
